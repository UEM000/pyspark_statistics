# %%
from src.experiment.experiment import Experiment
import pandas as pd

# %%
df = pd.read_csv("./datasets/data.csv")

# %%
result_path = "./"
output_path = "./test.txt"

# %%
experiment = Experiment(data=df, 
                        session=None,
                        result_path=result_path, 
                        report=False)
experiment.execute()
# Out:
# Grid Search Progress for experiment=all_tests_01, test=chisquare, algo=0: 100%|██████████| 1/1 [00:00<00:00,  3.29it/s]
# Grid Search Progress for experiment=all_tests_01, test=chisquare, algo=1: 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]
# Grid Search Progress for experiment=all_tests_01, test=ttest, algo=0: 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
# Grid Search Progress for experiment=all_tests_01, test=ttest, algo=1: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Grid Search Progress for experiment=all_tests_01, test=kstest, algo=0: 100%|██████████| 1/1 [00:00<00:00,  2.41it/s]
# Grid Search Progress for experiment=all_tests_01, test=kstest, algo=1: 100%|██████████| 1/1 [00:00<00:00,  4.41it/s]
