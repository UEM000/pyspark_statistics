# %%
from src.experiment.experiment import Experiment
import polars as pl

# %%
df = pl.scan_csv("./datasets/data.csv")

# %%
result_path = "./"
output_path = "./test.txt"

# %%
experiment = Experiment(data=df, 
                        session=None,
                        result_path=result_path, 
                        report=False)
experiment.execute()
# Out:
# Grid Search Progress for experiment=all_tests_01, test=chisquare, algo=0: 100%|██████████| 1/1 [00:00<00:00,  1.58it/s]
# Grid Search Progress for experiment=all_tests_01, test=chisquare, algo=1: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# Grid Search Progress for experiment=all_tests_01, test=ttest, algo=0: 100%|██████████| 1/1 [00:00<00:00,  1.61it/s]
# Grid Search Progress for experiment=all_tests_01, test=ttest, algo=1: 100%|██████████| 1/1 [00:00<00:00,  1.65it/s]
# Grid Search Progress for experiment=all_tests_01, test=kstest, algo=0: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]
# Grid Search Progress for experiment=all_tests_01, test=kstest, algo=1: 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
